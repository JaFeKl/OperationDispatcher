# %%
from __future__ import annotations

from operation_dispatcher.utils.example_history import build_example_history

history = build_example_history()

# %%
# show diagnostics report for the example history

from operation_dispatcher.diagnostics.history_analyzer import HistoryAnalyzer

analyzer = HistoryAnalyzer(history)
print(analyzer.get_report())
# Out:
# {'dispatcher_uptime_seconds': 4380.0, 'dispatcher_uptime_percentage': 93.58974358974359, 'dispatcher_runtime_seconds': 4080.0, 'dispatcher_runtime_percentage': 87.17948717948718}

# %%
# visualize gannt chart

from operation_dispatcher.visualization import show_history_gantt

figure = show_history_gantt(history)
